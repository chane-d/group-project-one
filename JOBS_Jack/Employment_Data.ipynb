# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# get csv files

colorado_file = 'csv_folder/colorado.csv'
oregon_file = 'csv_folder/oregon.csv'
washington_file = 'csv_folder/washington.csv'
alaska_file = 'csv_folder/alaska.csv'
us_employment_file = 'csv_folder/us_nonfarm_ttl_employed.csv'
us_unemployment_rate_file = 'csv_folder/us_unemployment_rate.csv'
us_unemployed_file = 'csv_folder/us_unemployed_ttl.csv'

# %%
# make dataframe

colorado_df = pd.read_csv(colorado_file)
oregon_df = pd.read_csv(oregon_file)
washington_df = pd.read_csv(washington_file)
alaska_df = pd.read_csv(alaska_file)
us_employment_df = pd.read_csv(us_employment_file)
us_unemployment_rate_df = pd.read_csv(us_unemployment_rate_file)
us_unemployed_df = pd.read_csv(us_unemployed_file)

# %%
# US

# %%
us_unemployment_rate_df.head()

us_output = []
us_year_list = us_unemployment_rate_df['Year'].unique()
us_year_list = us_year_list[3:]

for location in range(3,11):
    us_year = us_unemployment_rate_df.iloc[location]
    us_mean = round(us_year.iloc[1:].mean(), 2)
    us_output.append(us_mean)
    

us_ur_df = pd.DataFrame({
    'Year' : us_year_list,
    'US Unemployment Rate' : us_output
})

# %%
# Colorado

# %%
year_list = colorado_df['Year'].unique()
colorado_df = colorado_df[:-1]
colorado_df['unemployment rate'] = pd.to_numeric(colorado_df['unemployment rate'])

output = []

for year in year_list:
    by_year = colorado_df.loc[colorado_df['Year'] == year]
    mean_rate = round(by_year['unemployment rate'].mean(), 2)
    
    output.append(mean_rate)
    
output

amended_colorado_df = pd.DataFrame({
    'Year': year_list,
    'Colorado Unemployment Rate': output
})

# %%
us_col = us_ur_df.merge(amended_colorado_df, on='Year')
us_col_diff = us_col['US Unemployment Rate'] - us_col['Colorado Unemployment Rate']

# %%
# %matplotlib notebook

colorado_year = amended_colorado_df['Year']
colorado_ur = amended_colorado_df['Colorado Unemployment Rate']

plt.plot(colorado_year, colorado_ur, marker ='o', color='palevioletred', label = 'Colorado')
plt.plot(us_year_list, us_output, marker ='o', color='dimgrey', label = 'US')

plt.legend()

plt.axvline(x = 2014, color = 'green')
plt.rcParams['axes.facecolor'] = 'whitesmoke'

plt.title('Yearly Mean Unemployment Rate (Colorado and Total US)')
plt.xlabel('Year')
plt.ylabel('Unemployment Rate (%)')
# Out:
# <img src="data:image/png;base64,..." width="432">
# Text(0,0.5,'Unemployment Rate (%)')

# %%
plt.plot(us_year_list, us_col_diff, marker ='o', color='palevioletred')

plt.axvline(x = 2014, color = 'green')
plt.rcParams['axes.facecolor'] = 'whitesmoke'

plt.title('Difference Between US and Colorado Unemployment Rate by Year')
plt.xlabel('Year')
plt.ylabel('Unemployment Rate (%)')
# Out:
# <img src="data:image/png;base64,..." width="432">
# Text(0,0.5,'Unemployment Rate (%)')

# %%
# Oregon 

oregon_year_list = oregon_df['Year'].unique()
oregon_df = oregon_df[:-1]
oregon_df['unemployment rate'] = pd.to_numeric(oregon_df['unemployment rate'])

output = []

for year in year_list:
    by_year = oregon_df.loc[oregon_df['Year'] == year]
    mean_rate = round(by_year['unemployment rate'].mean(), 2)
    
    output.append(mean_rate)
    
output

amended_oregon_df = pd.DataFrame({
    'Year': year_list,
    'Oregon Unemployment Rate': output
})

# %%
us_ore = us_ur_df.merge(amended_oregon_df, on='Year')
us_ore_diff = us_ore['US Unemployment Rate'] - us_ore['Oregon Unemployment Rate']

# %%
# %matplotlib notebook

oregon_year = amended_oregon_df['Year']
oregon_ur = amended_oregon_df['Oregon Unemployment Rate']

plt.plot(oregon_year, oregon_ur, marker ='o', color='darkorange', label = 'Oregon')
plt.plot(us_year_list, us_output, marker ='o', color='dimgrey', label = 'US')

plt.legend()

plt.axvline(x = 2015, color = 'green')
plt.rcParams['axes.facecolor'] = 'whitesmoke'

plt.title('Yearly Mean Unemployment Rate (Oregon and Total US)')
plt.xlabel('Year')
plt.ylabel('Unemployment Rate (%)')
# Out:
# <img src="data:image/png;base64,..." width="432">
# Text(0,0.5,'Unemployment Rate (%)')

# %%
plt.plot(us_year_list[:], us_ore_diff, marker ='o', color='darkorange')

plt.axvline(x = 2015, color = 'green')
plt.rcParams['axes.facecolor'] = 'whitesmoke'

plt.title('Difference Between US and Oregon Unemployment Rate by Year')
plt.xlabel('Year')
plt.ylabel('Unemployment Rate (%)')
# Out:
# <img src="data:image/png;base64,..." width="432">
# Text(0,0.5,'Unemployment Rate (%)')

# %%
# Washington

year_list = washington_df['Year'].unique()
washington_df = washington_df[:-1]
washington_df['unemployment rate'] = pd.to_numeric(washington_df['unemployment rate'])

output = []

for year in year_list:
    by_year = washington_df.loc[washington_df['Year'] == year]
    mean_rate = round(by_year['unemployment rate'].mean(), 2)
    
    output.append(mean_rate)
    
output

amended_washington_df = pd.DataFrame({
    'Year': year_list,
    'Washington Unemployment Rate': output
})

# %%
us_wash = us_ur_df.merge(amended_washington_df, on='Year')
us_wash_diff = us_wash['US Unemployment Rate'] - us_wash['Washington Unemployment Rate']

# %%
# %matplotlib notebook

washington_year = amended_washington_df['Year']
washington_ur = amended_washington_df['Washington Unemployment Rate']

plt.plot(washington_year, washington_ur, marker ='o', color='mediumpurple', label = 'Washington')
plt.plot(us_year_list, us_output, marker ='o', color='dimgrey', label = 'US')

plt.legend()

plt.axvline(x = 2014, color = 'green')
plt.rcParams['axes.facecolor'] = 'whitesmoke'

plt.title('Yearly Mean Unemployment Rate (Washington and Total US)')
plt.xlabel('Year')
plt.ylabel('Unemployment Rate (%)')
# Out:
# <img src="data:image/png;base64,..." width="432">
# Text(0,0.5,'Unemployment Rate (%)')

# %%
plt.plot(us_year_list, us_wash_diff, marker ='o', color='mediumpurple')

plt.axvline(x = 2014, color = 'green')
plt.rcParams['axes.facecolor'] = 'whitesmoke'

plt.title('Difference Between US and Washington Unemployment Rate by Year')
plt.xlabel('Year')
plt.ylabel('Unemployment Rate (%)')
# Out:
# <img src="data:image/png;base64,..." width="432">
# Text(0,0.5,'Unemployment Rate (%)')

# %%
# Alaska

year_list = alaska_df['Year'].unique()
alaska_df = alaska_df[:-1]
alaska_df['unemployment rate'] = pd.to_numeric(alaska_df['unemployment rate'])

output = []

for year in year_list:
    by_year = alaska_df.loc[alaska_df['Year'] == year]
    mean_rate = round(by_year['unemployment rate'].mean(), 2)
    
    output.append(mean_rate)
    
output

amended_alaska_df = pd.DataFrame({
    'Year': year_list,
    'Alaska Unemployment Rate': output
})

# %%
us_al = us_ur_df.merge(amended_alaska_df, on='Year')
us_al_diff = us_al['US Unemployment Rate'] - us_al['Alaska Unemployment Rate']

# %%
# %matplotlib notebook

alaska_year = amended_alaska_df['Year']
alaska_ur = amended_alaska_df['Alaska Unemployment Rate']

plt.plot(alaska_year, alaska_ur, marker ='o', color='lightseagreen', label = 'Alaska')
plt.plot(us_year_list, us_output, marker ='o', color='dimgrey', label = 'US')

plt.legend()

plt.axvline(x = 2015, color = 'green')
plt.rcParams['axes.facecolor'] = 'whitesmoke'

plt.title('Yearly Mean Unemployment Rate (Alaska and Total US)')
plt.xlabel('Year')
plt.ylabel('Unemployment Rate (%)')
# Out:
# <img src="data:image/png;base64,..." width="432">
# Text(0,0.5,'Unemployment Rate (%)')

# %%
plt.plot(us_year_list[1:], us_al_diff, marker ='o', color='lightseagreen')

plt.axvline(x = 2015, color = 'green')
plt.rcParams['axes.facecolor'] = 'whitesmoke'

plt.title('Difference Between US and Alaska Unemployment Rate by Year')
plt.xlabel('Year')
plt.ylabel('Unemployment Rate (%)')
# Out:
# <img src="data:image/png;base64,..." width="432">
# Text(0,0.5,'Unemployment Rate (%)')
