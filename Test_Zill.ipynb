# %%
import pandas as pd

# %%
homeprice=pd.read_csv('Sale_Prices_Zip.csv')

# %%
homeprice.head()
# Out:
#    RegionID  RegionName StateName  SizeRank  2008-03  2008-04  2008-05  \
# 0   61639.0       10025  New York         1      NaN      NaN      NaN
# 1   84654.0       60657  Illinois         2      NaN      NaN      NaN
# 2   91982.0       77494     Texas         3      NaN      NaN      NaN
# 3   93144.0       79936     Texas         4      NaN      NaN      NaN
# 4   91940.0       77449     Texas         5      NaN      NaN      NaN
#
#    2008-06  2008-07  2008-08    ...       2018-02   2018-03    2018-04  \
# 0      NaN      NaN      NaN    ...      889000.0  871400.0  1018000.0
# 1      NaN      NaN      NaN    ...      378000.0  387700.0   345300.0
# 2      NaN      NaN      NaN    ...      331000.0  336600.0   333100.0
# 3      NaN      NaN      NaN    ...      127800.0  128500.0   126300.0
# 4      NaN      NaN      NaN    ...      178000.0  180500.0   182600.0
#
#      2018-05    2018-06   2018-07    2018-08    2018-09    2018-10    2018-11
# ...

# %%
homeprice=homeprice[['StateName']=='Washington']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-52bc092baab1> in <module>()
# ...
